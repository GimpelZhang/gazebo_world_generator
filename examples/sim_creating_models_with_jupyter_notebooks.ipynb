# %% [markdown]
# # Creating models with Jupyter notebooks

# %% [markdown]
# ## Testing friction properties
#
# The `pcg_gazebo_pkgs` includes also a simple interface to start Gazebo.
#
# It can be used to start Gazebo in the Python script or notebook, spawn models and interact with the simulation.

# %%
try:
    import rospy
    ROS1_AVAILABLE = True
except ImportError:
    ROS1_AVAILABLE = False
    
if not ROS1_AVAILABLE:
    print('No ROS 1 available, source the ROS 1 setup.bash to run Gazebo')
else:
    # If there is a Gazebo instance running, you can spawn 
    # the box into the simulation
    from pcg_gazebo.task_manager import Server
    # First create a simulation server
    server = Server()
    # Create a simulation manager named default
    server.create_simulation('pcg-example')
    simulation = server.get_simulation('pcg-example')

# %%
if ROS1_AVAILABLE:
    # Run an instance of the empty.world scenario
    # This is equivalent to run
    #      roslaunch gazebo_ros empty_world.launch
    # with all default parameters
    simulation.create_gazebo_empty_world_task()
    # A task named 'gazebo' the added to the tasks list
    print('Tasks created: ', simulation.get_task_list())
    # But it is still not running
    print('Is Gazebo running: {}'.format(
        simulation.is_task_running('gazebo')))
# Out:
# 2020-09-10 17:06:05,640 | WARNING | __init__ | Error testing Gazebo server, message=Command '['rostopic', 'list']' returned non-zero exit status 1
# Tasks created:  ['gazebo']
# Is Gazebo running: False

# %%
if ROS1_AVAILABLE:
    # Run Gazebo
    simulation.run_all_tasks()
# Out:
# 2020-09-10 17:06:21,160 | WARNING | __init__ | Error testing roscore, message=Command '['rostopic', 'list']' returned non-zero exit status 1
# 2020-09-10 17:06:21,399 | WARNING | __init__ | Error testing roscore, message=Command '['rostopic', 'list']' returned non-zero exit status 1
# 2020-09-10 17:06:21,650 | WARNING | __init__ | Error testing roscore, message=Command '['rostopic', 'list']' returned non-zero exit status 1

# %% [markdown]
# Once the simulation is running, an instance of the `GazeboProxy` object can be created to interact with it (e.g. spawn models).
# If not specified otherwise, the simulation is created with a random port for Gazebo and ROS master to enable multiple instances of the simulation to run in parallel.

# %%
from pcg_gazebo.generators import WorldGenerator
import random
if ROS1_AVAILABLE:
    # Create a Gazebo proxy
    gazebo_proxy = simulation.get_gazebo_proxy()
    print('ROS configuration:')
    print(gazebo_proxy.ros_config)
# Out:
# ROS configuration:
# ROS_MASTER_URI=http://localhost:18566, GAZEBO_MASTER_URI=http://localhost:26418

# %% [markdown]
# Create a single link box model.

# %%
from pcg_gazebo.simulation import SimulationModel

obj = SimulationModel('box')

# By changing the size, collision, visual and inertial 
# properties are already going to be updated
obj.add_cuboid_link(
    link_name='link',
    size=[0.8, 0.7, 0.9],
    mass=30)

# Print the initial state of a box in the model option
print(obj.to_sdf())
# Out:
# line 81.
# line 82.
# <model name="box">
#   <link name="link">
#     <visual name="visual">
#       <pose frame="">0 0 0 0 -0 0</pose>
#       <geometry>
#         <box>
#           <size>0.8 0.7 0.9</size>
#         </box>
#       </geometry>
#       <transparency>0.0</transparency>
#       <cast_shadows>1</cast_shadows>
#     </visual>
#     <kinematic>0</kinematic>
#     <gravity>1</gravity>
#     <self_collide>0</self_collide>
#     <pose frame="">0 0 0 0 -0 0</pose>
#     <collision name="collision">
#       <geometry>
#         <box>
#           <size>0.8 0.7 0.9</size>
#         </box>
#       </geometry>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </collision>
#     <inertial>
#       <inertia>
#         <ixy>0.0</ixy>
#         <ixx>3.25</ixx>
#         <iyz>0.0</iyz>
#         <iyy>3.6250000000000004</iyy>
#         <ixz>0.0</ixz>
#         <izz>2.825</izz>
#       </inertia>
#       <mass>30.0</mass>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </inertial>
#   </link>
#   <self_collide>0</self_collide>
#   <pose frame="">0 0 0 0 -0 0</pose>
#   <static>0</static>
#   <allow_auto_disable>0</allow_auto_disable>
# </model>

# %%
# Set default friction parameters
obj.links['link'].collisions[0].enable_property('friction')
print(obj.to_sdf('model'))
# Out:
# line 81.
# line 82.
# <model name="box">
#   <link name="link">
#     <visual name="visual">
#       <pose frame="">0 0 0 0 -0 0</pose>
#       <geometry>
#         <box>
#           <size>0.8 0.7 0.9</size>
#         </box>
#       </geometry>
#       <transparency>0.0</transparency>
#       <cast_shadows>1</cast_shadows>
#     </visual>
#     <kinematic>0</kinematic>
#     <gravity>1</gravity>
#     <self_collide>0</self_collide>
#     <pose frame="">0 0 0 0 -0 0</pose>
#     <collision name="collision">
#       <geometry>
#         <box>
#           <size>0.8 0.7 0.9</size>
#         </box>
#       </geometry>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </collision>
#     <inertial>
#       <inertia>
#         <ixy>0.0</ixy>
#         <ixx>3.25</ixx>
#         <iyz>0.0</iyz>
#         <iyy>3.6250000000000004</iyy>
#         <ixz>0.0</ixz>
#         <izz>2.825</izz>
#       </inertia>
#       <mass>30.0</mass>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </inertial>
#   </link>
#   <self_collide>0</self_collide>
#   <pose frame="">0 0 0 0 -0 0</pose>
#   <static>0</static>
#   <allow_auto_disable>0</allow_auto_disable>
# </model>

# %%
obj.links['link'].collisions[0].set_ode_friction_params(
    mu=0.9,
    mu2=0.5,
    slip1=0.3, 
    slip2=0.5,
    fdir1=[0, 0, 0]
)
print(obj.to_sdf('model'))
# Out:
# line 81.
# line 82.
# <model name="box">
#   <link name="link">
#     <visual name="visual">
#       <pose frame="">0 0 0 0 -0 0</pose>
#       <geometry>
#         <box>
#           <size>0.8 0.7 0.9</size>
#         </box>
#       </geometry>
#       <transparency>0.0</transparency>
#       <cast_shadows>1</cast_shadows>
#     </visual>
#     <kinematic>0</kinematic>
#     <gravity>1</gravity>
#     <self_collide>0</self_collide>
#     <pose frame="">0 0 0 0 -0 0</pose>
#     <collision name="collision">
#       <surface>
#         <friction>
#           <ode>
#             <slip1>0.3</slip1>
#             <slip2>0.5</slip2>
#             <fdir1>0 0 0</fdir1>
#             <mu2>0.5</mu2>
#             <mu>0.9</mu>
#           </ode>
#         </friction>
#       </surface>
#       <pose frame="">0 0 0 0 -0 0</pose>
#       <geometry>
#         <box>
#           <size>0.8 0.7 0.9</size>
#         </box>
#       </geometry>
#     </collision>
#     <inertial>
#       <inertia>
#         <ixy>0.0</ixy>
#         <ixx>3.25</ixx>
#         <iyz>0.0</iyz>
#         <iyy>3.6250000000000004</iyy>
#         <ixz>0.0</ixz>
#         <izz>2.825</izz>
#       </inertia>
#       <mass>30.0</mass>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </inertial>
#   </link>
#   <self_collide>0</self_collide>
#   <pose frame="">0 0 0 0 -0 0</pose>
#   <static>0</static>
#   <allow_auto_disable>0</allow_auto_disable>
# </model>

# %%
mu = [0.1, 0.3, 0.5, 0.7, 1.0] 
for i in range(len(mu)):
    print('\t - #{} mu = {}'.format(i, mu[i]))
    obj.links['link'].collisions[0].set_ode_friction_params(
        mu=mu[i],
        mu2=mu[i],
        slip1=0.0, 
        slip2=0.0)
    print(obj.links['link'].collisions[0].to_sdf())
    # Set a random XKCD color to each box
    obj.links['link'].visuals[0].set_xkcd_color()
    obj.name = 'box_mu_{}'.format(mu[i])
    obj.pose = [0, i, 2, 0, 0, 0]
    if ROS1_AVAILABLE:
        obj.spawn(gazebo_proxy=gazebo_proxy)
# Out:
# 	 - #0 mu = 0.1
# <collision name="collision">
#   <surface>
#     <friction>
#       <ode>
#         <slip1>0.0</slip1>
#         <slip2>0.0</slip2>
#         <fdir1>0 0 0</fdir1>
#         <mu2>0.1</mu2>
#         <mu>0.1</mu>
#       </ode>
#     </friction>
#   </surface>
#   <pose frame="">0 0 0 0 -0 0</pose>
#   <geometry>
#     <box>
#       <size>0.8 0.7 0.9</size>
#     </box>
#   </geometry>
# </collision>
#
# line 81.
# line 82.
# 	 - #1 mu = 0.3
# <collision name="collision">
#   <surface>
#     <friction>
#       <ode>
#         <slip1>0.0</slip1>
#         <slip2>0.0</slip2>
#         <fdir1>0 0 0</fdir1>
#         <mu2>0.3</mu2>
#         <mu>0.3</mu>
#       </ode>
#     </friction>
#   </surface>
#   <pose frame="">0 0 0 0 -0 0</pose>
#   <geometry>
#     <box>
#       <size>0.8 0.7 0.9</size>
#     </box>
#   </geometry>
# </collision>
#
# line 81.
# line 82.
# 	 - #2 mu = 0.5
# <collision name="collision">
#   <surface>
#     <friction>
#       <ode>
#         <slip1>0.0</slip1>
#         <slip2>0.0</slip2>
#         <fdir1>0 0 0</fdir1>
#         <mu2>0.5</mu2>
#         <mu>0.5</mu>
#       </ode>
#     </friction>
#   </surface>
#   <pose frame="">0 0 0 0 -0 0</pose>
#   <geometry>
#     <box>
#       <size>0.8 0.7 0.9</size>
#     </box>
#   </geometry>
# </collision>
#
# line 81.
# line 82.
# 	 - #3 mu = 0.7
# <collision name="collision">
#   <surface>
#     <friction>
#       <ode>
#         <slip1>0.0</slip1>
#         <slip2>0.0</slip2>
#         <fdir1>0 0 0</fdir1>
#         <mu2>0.7</mu2>
#         <mu>0.7</mu>
#       </ode>
#     </friction>
#   </surface>
#   <pose frame="">0 0 0 0 -0 0</pose>
#   <geometry>
#     <box>
#       <size>0.8 0.7 0.9</size>
#     </box>
#   </geometry>
# </collision>
#
# line 81.
# line 82.
# 	 - #4 mu = 1.0
# <collision name="collision">
#   <surface>
#     <friction>
#       <ode>
#         <slip1>0.0</slip1>
#         <slip2>0.0</slip2>
#         <fdir1>0 0 0</fdir1>
#         <mu2>1.0</mu2>
#         <mu>1.0</mu>
#       </ode>
#     </friction>
#   </surface>
#   <pose frame="">0 0 0 0 -0 0</pose>
#   <geometry>
#     <box>
#       <size>0.8 0.7 0.9</size>
#     </box>
#   </geometry>
# </collision>
#
# line 81.
# line 82.

# %% [markdown]
# ![sim_boxes](images/sim_boxes.png)
#
# Apply a force to each box to see the effects of the different friction coefficients.

# %%
if ROS1_AVAILABLE:
    for i in range(len(mu)):
        gazebo_proxy.apply_body_wrench(
            model_name='box_mu_{}'.format(mu[i]),
            link_name='link',
            force=[300, 0, 0],
            torque=[0, 0, 0],
            start_time=0,
            duration=2
            )

# %% [markdown]
# ![sim_boxes_after_wrench](images/sim_boxes_after_wrench.png)

# %% [markdown]
# ## Create a mobile base
#
# Recreating the [Gazebo tutorial for a mobile base](http://gazebosim.org/tutorials/?tut=attach_gripper#MobileBase)

# %%
from pcg_gazebo.simulation import create_object

# %%
# Creating the main body of the chassis
chassis = create_object('box')
chassis.size = [2, 1, 0.3]
chassis.add_inertial(20)
chassis.visual.enable_property('material')
chassis.visual.set_xkcd_color()

print(chassis.to_sdf('link'))
# Out:
# <link name="box">
#   <visual name="visual">
#     <geometry>
#       <box>
#         <size>2 1 0.3</size>
#       </box>
#     </geometry>
#     <pose frame="">0 0 0 0 -0 0</pose>
#     <material>
#       <ambient>0.0156863 0.521569 0.819608 1</ambient>
#       <diffuse>0.01568627450980392 0.5215686274509804 0.8196078431372549 1</diffuse>
#     </material>
#     <transparency>0.0</transparency>
#     <cast_shadows>1</cast_shadows>
#   </visual>
#   <kinematic>0</kinematic>
#   <gravity>1</gravity>
#   <self_collide>0</self_collide>
#   <pose frame="">0 0 0 0 -0 0</pose>
#   <collision name="collision">
#     <pose frame="">0 0 0 0 -0 0</pose>
#     <geometry>
#       <box>
#         <size>2 1 0.3</size>
#       </box>
#     </geometry>
#   </collision>
#   <inertial>
#     <inertia>
#       <ixy>0.0</ixy>
#       <ixx>1.8166666666666667</ixx>
#       <izz>8.333333333333332</izz>
#       <iyy>6.8166666666666655</iyy>
#       <ixz>0.0</ixz>
#       <iyz>0.0</iyz>
#     </inertia>
#     <mass>20.0</mass>
#     <pose frame="">0 0 0 0 -0 0</pose>
#   </inertial>
# </link>

# %%
# Creating the caster wheel
caster_wheel = create_object('sphere')
caster_wheel.radius = 0.125
caster_wheel.add_inertial(1)
caster_wheel.visual.enable_property('material')
caster_wheel.visual.set_xkcd_color()

# Setting friction parameters to zero
caster_wheel.collision.enable_property('friction')
caster_wheel.collision.set_ode_friction_params(
    mu=0.0,
    mu2=0.0,
    slip1=0, 
    slip2=0,
    fdir1=[0, 0, 0]
)

caster_wheel.collision.set_bullet_friction_params(
    friction=0.0, 
    friction2=0.0, 
    fdir1=[0, 0, 0], 
    rolling_friction=1
)

print(caster_wheel.to_sdf('link'))
# Out:
# <link name="sphere">
#   <visual name="visual">
#     <geometry>
#       <sphere>
#         <radius>0.125</radius>
#       </sphere>
#     </geometry>
#     <pose frame="">0 0 0 0 -0 0</pose>
#     <material>
#       <ambient>0.643137 0.74902 0.12549 1</ambient>
#       <diffuse>0.6431372549019608 0.7490196078431373 0.12549019607843137 1</diffuse>
#     </material>
#     <transparency>0.0</transparency>
#     <cast_shadows>1</cast_shadows>
#   </visual>
#   <kinematic>0</kinematic>
#   <gravity>1</gravity>
#   <self_collide>0</self_collide>
#   <pose frame="">0 0 0 0 -0 0</pose>
#   <collision name="collision">
#     <surface>
#       <friction>
#         <ode>
#           <slip1>0.0</slip1>
#           <slip2>0.0</slip2>
#           <mu>0.0</mu>
#           <mu2>0.0</mu2>
#           <fdir1>0 0 0</fdir1>
#         </ode>
#         <bullet>
#           <friction>0.0</friction>
#           <rolling_friction>1.0</rolling_friction>
#           <friction2>0.0</friction2>
#           <fdir1>0 0 0</fdir1>
#         </bullet>
#       </friction>
#     </surface>
#     <geometry>
#       <sphere>
#         <radius>0.125</radius>
#       </sphere>
#     </geometry>
#     <pose frame="">0 0 0 0 -0 0</pose>
#   </collision>
#   <inertial>
#     <inertia>
#       <ixy>0.0</ixy>
#       <ixx>0.00625</ixx>
#       <izz>0.00625</izz>
#       <iyy>0.00625</iyy>
#       <ixz>0.0</ixz>
#       <iyz>0.0</iyz>
#     </inertia>
#     <mass>1.0</mass>
#     <pose frame="">0 0 0 0 -0 0</pose>
#   </inertial>
# </link>

# %%
right_wheel = create_object('cylinder')
right_wheel.pose = [-0.8, -0.5 - 0.025, -0.125, 0, 1.5707, 1.5707]
right_wheel.radius = 0.125
right_wheel.length = 0.05
right_wheel.add_inertial(1)
right_wheel.visual.enable_property('material')
right_wheel.visual.set_xkcd_color()

left_wheel = create_object('cylinder')
left_wheel.pose = [-0.8, 0.5 + 0.025, -0.125, 0, 1.5707, 1.5707]
left_wheel.radius = 0.125
left_wheel.length = 0.05
left_wheel.add_inertial(1)
left_wheel.visual.enable_property('material')
left_wheel.visual.set_xkcd_color()

print(right_wheel.to_sdf('link'))
# Out:
# <link name="cylinder">
#   <visual name="visual">
#     <geometry>
#       <cylinder>
#         <length>0.05</length>
#         <radius>0.125</radius>
#       </cylinder>
#     </geometry>
#     <pose frame="">0 0 0 0 -0 0</pose>
#     <material>
#       <ambient>0.494118 0.117647 0.611765 1</ambient>
#       <diffuse>0.49411764705882355 0.11764705882352941 0.611764705882353 1</diffuse>
#     </material>
#     <transparency>0.0</transparency>
#     <cast_shadows>1</cast_shadows>
#   </visual>
#   <kinematic>0</kinematic>
#   <gravity>1</gravity>
#   <self_collide>0</self_collide>
#   <pose frame="">-0.8 -0.525 -0.125 5.76279e-13 1.5707 1.5707</pose>
#   <collision name="collision">
#     <pose frame="">0 0 0 0 -0 0</pose>
#     <geometry>
#       <cylinder>
#         <length>0.05</length>
#         <radius>0.125</radius>
#       </cylinder>
#     </geometry>
#   </collision>
#   <inertial>
#     <inertia>
#       <ixy>0.0</ixy>
#       <ixx>0.004114583333333333</ixx>
#       <izz>0.0078125</izz>
#       <iyy>0.004114583333333333</iyy>
#       <ixz>0.0</ixz>
#       <iyz>0.0</iyz>
#     </inertia>
#     <mass>1.0</mass>
#     <pose frame="">0 0 0 0 -0 0</pose>
#   </inertial>
# </link>

# %%
# Assembling the robot mobile base
mobile_base = SimulationModel('mobile_base')

# Adding chassis
mobile_base.add_link('chassis', chassis)

# Adding caster wheel
caster_wheel.pose = [0.8, 0, -0.125, 0, 0, 0]
mobile_base.add_link('caster_wheel', caster_wheel)
mobile_base.add_joint('caster_wheel_joint', parent='chassis', child='caster_wheel', joint_type='fixed')

# Adding left wheel
mobile_base.add_link('left_wheel', left_wheel)
mobile_base.add_joint('left_wheel_joint', parent='chassis', child='left_wheel', joint_type='revolute')

# Adding right wheel
mobile_base.add_link('right_wheel', right_wheel)
mobile_base.add_joint('right_wheel_joint', parent='chassis', child='right_wheel', joint_type='revolute')

print(mobile_base.to_sdf())
# Out:
# line 81.
# line 82.
# <model name="mobile_base">
#   <self_collide>0</self_collide>
#   <static>0</static>
#   <link name="right_wheel">
#     <visual name="visual">
#       <pose frame="">0 0 0 0 -0 0</pose>
#       <geometry>
#         <cylinder>
#           <length>0.05</length>
#           <radius>0.125</radius>
#         </cylinder>
#       </geometry>
#       <material>
#         <ambient>0.494118 0.117647 0.611765 1</ambient>
#         <diffuse>0.49411764705882355 0.11764705882352941 0.611764705882353 1</diffuse>
#       </material>
#       <transparency>0.0</transparency>
#       <cast_shadows>1</cast_shadows>
#     </visual>
#     <kinematic>0</kinematic>
#     <gravity>1</gravity>
#     <self_collide>0</self_collide>
#     <pose frame="">-0.8 -0.525 -0.125 5.76279e-13 1.5707 1.5707</pose>
#     <collision name="collision">
#       <geometry>
#         <cylinder>
#           <length>0.05</length>
#           <radius>0.125</radius>
#         </cylinder>
#       </geometry>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </collision>
#     <inertial>
#       <inertia>
#         <ixy>0.0</ixy>
#         <ixx>0.004114583333333333</ixx>
#         <iyz>0.0</iyz>
#         <iyy>0.004114583333333333</iyy>
#         <ixz>0.0</ixz>
#         <izz>0.0078125</izz>
#       </inertia>
#       <mass>1.0</mass>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </inertial>
#   </link>
#   <link name="left_wheel">
#     <visual name="visual">
#       <pose frame="">0 0 0 0 -0 0</pose>
#       <geometry>
#         <cylinder>
#           <length>0.05</length>
#           <radius>0.125</radius>
#         </cylinder>
#       </geometry>
#       <material>
#         <ambient>0.592157 0.541176 0.517647 1</ambient>
#         <diffuse>0.592156862745098 0.5411764705882353 0.5176470588235295 1</diffuse>
#       </material>
#       <transparency>0.0</transparency>
#       <cast_shadows>1</cast_shadows>
#     </visual>
#     <kinematic>0</kinematic>
#     <gravity>1</gravity>
#     <self_collide>0</self_collide>
#     <pose frame="">-0.8 0.525 -0.125 5.76279e-13 1.5707 1.5707</pose>
#     <collision name="collision">
#       <geometry>
#         <cylinder>
#           <length>0.05</length>
#           <radius>0.125</radius>
#         </cylinder>
#       </geometry>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </collision>
#     <inertial>
#       <inertia>
#         <ixy>0.0</ixy>
#         <ixx>0.004114583333333333</ixx>
#         <iyz>0.0</iyz>
#         <iyy>0.004114583333333333</iyy>
#         <ixz>0.0</ixz>
#         <izz>0.0078125</izz>
#       </inertia>
#       <mass>1.0</mass>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </inertial>
#   </link>
#   <link name="chassis">
#     <visual name="visual">
#       <pose frame="">0 0 0 0 -0 0</pose>
#       <geometry>
#         <box>
#           <size>2 1 0.3</size>
#         </box>
#       </geometry>
#       <material>
#         <ambient>0.0156863 0.521569 0.819608 1</ambient>
#         <diffuse>0.01568627450980392 0.5215686274509804 0.8196078431372549 1</diffuse>
#       </material>
#       <transparency>0.0</transparency>
#       <cast_shadows>1</cast_shadows>
#     </visual>
#     <kinematic>0</kinematic>
#     <gravity>1</gravity>
#     <self_collide>0</self_collide>
#     <pose frame="">0 0 0 0 -0 0</pose>
#     <collision name="collision">
#       <geometry>
#         <box>
#           <size>2 1 0.3</size>
#         </box>
#       </geometry>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </collision>
#     <inertial>
#       <inertia>
#         <ixy>0.0</ixy>
#         <ixx>1.8166666666666667</ixx>
#         <iyz>0.0</iyz>
#         <iyy>6.8166666666666655</iyy>
#         <ixz>0.0</ixz>
#         <izz>8.333333333333332</izz>
#       </inertia>
#       <mass>20.0</mass>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </inertial>
#   </link>
#   <link name="caster_wheel">
#     <visual name="visual">
#       <pose frame="">0 0 0 0 -0 0</pose>
#       <geometry>
#         <sphere>
#           <radius>0.125</radius>
#         </sphere>
#       </geometry>
#       <material>
#         <ambient>0.643137 0.74902 0.12549 1</ambient>
#         <diffuse>0.6431372549019608 0.7490196078431373 0.12549019607843137 1</diffuse>
#       </material>
#       <transparency>0.0</transparency>
#       <cast_shadows>1</cast_shadows>
#     </visual>
#     <kinematic>0</kinematic>
#     <gravity>1</gravity>
#     <self_collide>0</self_collide>
#     <pose frame="">0.8 0 -0.125 0 -0 0</pose>
#     <collision name="collision">
#       <surface>
#         <friction>
#           <ode>
#             <slip1>0.0</slip1>
#             <slip2>0.0</slip2>
#             <fdir1>0 0 0</fdir1>
#             <mu2>0.0</mu2>
#             <mu>0.0</mu>
#           </ode>
#           <bullet>
#             <friction>0.0</friction>
#             <rolling_friction>1.0</rolling_friction>
#             <friction2>0.0</friction2>
#             <fdir1>0 0 0</fdir1>
#           </bullet>
#         </friction>
#       </surface>
#       <pose frame="">0 0 0 0 -0 0</pose>
#       <geometry>
#         <sphere>
#           <radius>0.125</radius>
#         </sphere>
#       </geometry>
#     </collision>
#     <inertial>
#       <inertia>
#         <ixy>0.0</ixy>
#         <ixx>0.00625</ixx>
#         <iyz>0.0</iyz>
#         <iyy>0.00625</iyy>
#         <ixz>0.0</ixz>
#         <izz>0.00625</izz>
#       </inertia>
#       <mass>1.0</mass>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </inertial>
#   </link>
#   <pose frame="">0 0 0 0 -0 0</pose>
#   <allow_auto_disable>0</allow_auto_disable>
#   <joint name="right_wheel_joint" type="revolute">
#     <axis>
#       <limit>
#         <effort>-1.0</effort>
#         <lower>-1e+16</lower>
#         <velocity>-1.0</velocity>
#         <upper>1e+16</upper>
#       </limit>
#       <use_parent_model_frame>0</use_parent_model_frame>
#       <dynamics>
#         <friction>0.0</friction>
#         <damping>0.0</damping>
#         <spring_stiffness>0.0</spring_stiffness>
#         <spring_reference>0.0</spring_reference>
#       </dynamics>
#       <xyz>0 0 1</xyz>
#     </axis>
#     <parent>chassis</parent>
#     <pose frame="">0 0 0 0 -0 0</pose>
#     <child>right_wheel</child>
#   </joint>
#   <joint name="caster_wheel_joint" type="fixed">
#     <parent>chassis</parent>
#     <pose frame="">0 0 0 0 -0 0</pose>
#     <child>caster_wheel</child>
#   </joint>
#   <joint name="left_wheel_joint" type="revolute">
#     <axis>
#       <limit>
#         <effort>-1.0</effort>
#         <lower>-1e+16</lower>
#         <velocity>-1.0</velocity>
#         <upper>1e+16</upper>
#       </limit>
#       <use_parent_model_frame>0</use_parent_model_frame>
#       <dynamics>
#         <friction>0.0</friction>
#         <damping>0.0</damping>
#         <spring_stiffness>0.0</spring_stiffness>
#         <spring_reference>0.0</spring_reference>
#       </dynamics>
#       <xyz>0 0 1</xyz>
#     </axis>
#     <parent>chassis</parent>
#     <pose frame="">0 0 0 0 -0 0</pose>
#     <child>left_wheel</child>
#   </joint>
# </model>

# %%
print(mobile_base.to_urdf())
# Out:
# line 81.
# line 82.
# <robot name="mobile_base">
#   <link name="right_wheel">
#     <visual name="visual">
#       <geometry>
#         <cylinder length="0.05" radius="0.125"/>
#       </geometry>
#       <material name="">
#         <color rgba="0.49411764705882355 0.11764705882352941 0.611764705882353 1"/>
#       </material>
#       <origin rpy="0.0 -0.0 0.0" xyz="0 0 0"/>
#     </visual>
#     <collision name="collision">
#       <geometry>
#         <cylinder length="0.05" radius="0.125"/>
#       </geometry>
#       <origin rpy="0.0 -0.0 0.0" xyz="0 0 0"/>
#     </collision>
#     <inertial>
#       <inertia ixx="0.004114583333333333" ixy="0.0" ixz="0.0" iyy="0.004114583333333333" iyz="0.0" izz="0.0078125"/>
#       <mass value="1.0"/>
#       <origin rpy="0.0 -0.0 0.0" xyz="0 0 0"/>
#     </inertial>
#   </link>
#   <link name="left_wheel">
#     <visual name="visual">
#       <geometry>
#         <cylinder length="0.05" radius="0.125"/>
#       </geometry>
#       <material name="">
#         <color rgba="0.592156862745098 0.5411764705882353 0.5176470588235295 1"/>
#       </material>
#       <origin rpy="0.0 -0.0 0.0" xyz="0 0 0"/>
#     </visual>
#     <collision name="collision">
#       <geometry>
#         <cylinder length="0.05" radius="0.125"/>
#       </geometry>
#       <origin rpy="0.0 -0.0 0.0" xyz="0 0 0"/>
#     </collision>
#     <inertial>
#       <inertia ixx="0.004114583333333333" ixy="0.0" ixz="0.0" iyy="0.004114583333333333" iyz="0.0" izz="0.0078125"/>
#       <mass value="1.0"/>
#       <origin rpy="0.0 -0.0 0.0" xyz="0 0 0"/>
#     </inertial>
#   </link>
#   <link name="chassis">
#     <visual name="visual">
#       <geometry>
#         <box size="2 1 0.3"/>
#       </geometry>
#       <material name="">
#         <color rgba="0.01568627450980392 0.5215686274509804 0.8196078431372549 1"/>
#       </material>
#       <origin rpy="0.0 -0.0 0.0" xyz="0 0 0"/>
#     </visual>
#     <collision name="collision">
#       <geometry>
#         <box size="2 1 0.3"/>
#       </geometry>
#       <origin rpy="0.0 -0.0 0.0" xyz="0 0 0"/>
#     </collision>
#     <inertial>
#       <inertia ixx="1.8166666666666667" ixy="0.0" ixz="0.0" iyy="6.8166666666666655" iyz="0.0" izz="8.333333333333332"/>
#       <mass value="20.0"/>
#       <origin rpy="0.0 -0.0 0.0" xyz="0 0 0"/>
#     </inertial>
#   </link>
#   <link name="caster_wheel">
#     <visual name="visual">
#       <geometry>
#         <sphere radius="0.125"/>
#       </geometry>
#       <material name="">
#         <color rgba="0.6431372549019608 0.7490196078431373 0.12549019607843137 1"/>
#       </material>
#       <origin rpy="0.0 -0.0 0.0" xyz="0 0 0"/>
#     </visual>
#     <collision name="collision">
#       <geometry>
#         <sphere radius="0.125"/>
#       </geometry>
#       <origin rpy="0.0 -0.0 0.0" xyz="0 0 0"/>
#     </collision>
#     <inertial>
#       <inertia ixx="0.00625" ixy="0.0" ixz="0.0" iyy="0.00625" iyz="0.0" izz="0.00625"/>
#       <mass value="1.0"/>
#       <origin rpy="0.0 -0.0 0.0" xyz="0 0 0"/>
#     </inertial>
#   </link>
#   <joint name="right_wheel_joint" type="revolute">
#     <limit effort="-1.0" lower="-1e+16" upper="1e+16" velocity="-1.0"/>
#     <parent link="chassis"/>
#     <child link="right_wheel"/>
#     <axis xyz="0 0 1"/>
#     <dynamics damping="0.0" friction="0.0"/>
#     <origin rpy="5.762794389300482e-13 1.5706999999999998 1.5706999999997604" xyz="-0.8 -0.525 -0.125"/>
#   </joint>
#   <joint name="caster_wheel_joint" type="fixed">
#     <limit effort="0" lower="0" upper="0" velocity="0"/>
#     <parent link="chassis"/>
#     <origin rpy="0.0 -0.0 0.0" xyz="0.8 0.0 -0.125"/>
#     <child link="caster_wheel"/>
#   </joint>
#   <joint name="left_wheel_joint" type="revolute">
#     <limit effort="-1.0" lower="-1e+16" upper="1e+16" velocity="-1.0"/>
#     <parent link="chassis"/>
#     <child link="left_wheel"/>
#     <axis xyz="0 0 1"/>
#     <dynamics damping="0.0" friction="0.0"/>
#     <origin rpy="5.762794389300482e-13 1.5706999999999998 1.5706999999997604" xyz="-0.8 0.525 -0.125"/>
#   </joint>
# </robot>

# %%
if ROS1_AVAILABLE:
    mobile_base.spawn(
        gazebo_proxy=gazebo_proxy,
        pos=[0, 0, 0.5])
# Out:
# line 81.
# line 82.

# %% [markdown]
# ![sim_mobile_base](images/sim_mobile_base.png)

# %% [markdown]
# ## Add sensors to mobile base

# %%
# Add IMU sensor
mobile_base.add_imu_sensor(
    parent='chassis',
    add_visual=True, 
    add_collision=True, 
    visualize=True,
    mass=0.01,
    size=[0.1, 0.1, 0.1],
    topic='/imu',
    link_shape='cuboid',
    link_name='imu_link')

# Add contact sensor
mobile_base.add_contact_sensor(
    pose=[1, 0, 0, 0, 0, 0],
    parent='chassis',
    add_visual=True, 
    add_collision=True, 
    add_ros_plugin=True,
    mass=0.01,
    radius=0.05,
    length=0.1,
    link_shape='cylindrical',
    link_name='contact_link')

# Add camera sensor
mobile_base.add_camera_sensor(
    pose=[1, 0, 0.2, 0, 0, 0],
    parent='chassis',
    add_visual=True, 
    add_collision=True, 
    add_ros_plugin=True,
    visualize=True,
    mass=0.01,
    size=[0.1, 0.1, 0.1],
    link_shape='cuboid',
    link_name='camera_link')
# Out:
# True

# %%
print(mobile_base.to_sdf())
# Out:
# line 81.
# line 82.
# <model name="mobile_base">
#   <self_collide>0</self_collide>
#   <static>0</static>
#   <link name="left_wheel">
#     <visual name="visual">
#       <pose frame="">0 0 0 0 -0 0</pose>
#       <geometry>
#         <cylinder>
#           <length>0.05</length>
#           <radius>0.125</radius>
#         </cylinder>
#       </geometry>
#       <material>
#         <ambient>0.592157 0.541176 0.517647 1</ambient>
#         <diffuse>0.592156862745098 0.5411764705882353 0.5176470588235295 1</diffuse>
#       </material>
#       <transparency>0.0</transparency>
#       <cast_shadows>1</cast_shadows>
#     </visual>
#     <kinematic>0</kinematic>
#     <gravity>1</gravity>
#     <self_collide>0</self_collide>
#     <pose frame="">-0.8 0.525 -0.125 5.76279e-13 1.5707 1.5707</pose>
#     <collision name="collision">
#       <geometry>
#         <cylinder>
#           <length>0.05</length>
#           <radius>0.125</radius>
#         </cylinder>
#       </geometry>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </collision>
#     <inertial>
#       <inertia>
#         <ixy>0.0</ixy>
#         <ixx>0.004114583333333333</ixx>
#         <iyz>0.0</iyz>
#         <iyy>0.004114583333333333</iyy>
#         <ixz>0.0</ixz>
#         <izz>0.0078125</izz>
#       </inertia>
#       <mass>1.0</mass>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </inertial>
#   </link>
#   <link name="imu_link">
#     <visual name="visual">
#       <pose frame="">0 0 0 0 -0 0</pose>
#       <geometry>
#         <box>
#           <size>0.1 0.1 0.1</size>
#         </box>
#       </geometry>
#       <transparency>0.0</transparency>
#       <cast_shadows>1</cast_shadows>
#     </visual>
#     <kinematic>0</kinematic>
#     <gravity>1</gravity>
#     <self_collide>0</self_collide>
#     <pose frame="">0 0 0 0 -0 0</pose>
#     <collision name="collision">
#       <geometry>
#         <box>
#           <size>0.1 0.1 0.1</size>
#         </box>
#       </geometry>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </collision>
#     <sensor name="imu" type="imu">
#       <update_rate>50.0</update_rate>
#       <topic>/imu</topic>
#       <plugin filename="libgazebo_ros_imu_sensor.so" name="imu">
#         <gaussianNoise>0</gaussianNoise>
#         <alwaysOn>1</alwaysOn>
#         <bodyName>imu_link</bodyName>
#         <updateRateHZ>50</updateRateHZ>
#         <robotNamespace></robotNamespace>
#         <topicName>/imu</topicName>
#         <frameName>world</frameName>
#       </plugin>
#       <always_on>1</always_on>
#       <imu>
#         <angular_velocity>
#           <x>
#             <noise type="none">
#               <bias_stddev>0.0</bias_stddev>
#               <stddev>0.0</stddev>
#               <precision>0.0</precision>
#               <mean>0.0</mean>
#               <bias_mean>0.0</bias_mean>
#             </noise>
#           </x>
#           <y>
#             <noise type="none">
#               <bias_stddev>0.0</bias_stddev>
#               <stddev>0.0</stddev>
#               <precision>0.0</precision>
#               <mean>0.0</mean>
#               <bias_mean>0.0</bias_mean>
#             </noise>
#           </y>
#           <z>
#             <noise type="none">
#               <bias_stddev>0.0</bias_stddev>
#               <stddev>0.0</stddev>
#               <precision>0.0</precision>
#               <mean>0.0</mean>
#               <bias_mean>0.0</bias_mean>
#             </noise>
#           </z>
#         </angular_velocity>
#         <linear_acceleration>
#           <x>
#             <noise type="none">
#               <bias_stddev>0.0</bias_stddev>
#               <stddev>0.0</stddev>
#               <precision>0.0</precision>
#               <mean>0.0</mean>
#               <bias_mean>0.0</bias_mean>
#             </noise>
#           </x>
#           <y>
#             <noise type="none">
#               <bias_stddev>0.0</bias_stddev>
#               <stddev>0.0</stddev>
#               <precision>0.0</precision>
#               <mean>0.0</mean>
#               <bias_mean>0.0</bias_mean>
#             </noise>
#           </y>
#           <z>
#             <noise type="none">
#               <bias_stddev>0.0</bias_stddev>
#               <stddev>0.0</stddev>
#               <precision>0.0</precision>
#               <mean>0.0</mean>
#               <bias_mean>0.0</bias_mean>
#             </noise>
#           </z>
#         </linear_acceleration>
#         <topic>/imu</topic>
#       </imu>
#       <pose frame="">0 0 0 0 -0 0</pose>
#       <visualize>1</visualize>
#     </sensor>
#     <inertial>
#       <inertia>
#         <ixy>0.0</ixy>
#         <ixx>1.6666666666666667e-05</ixx>
#         <iyz>0.0</iyz>
#         <iyy>1.6666666666666667e-05</iyy>
#         <ixz>0.0</ixz>
#         <izz>1.6666666666666667e-05</izz>
#       </inertia>
#       <mass>0.01</mass>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </inertial>
#   </link>
#   <link name="right_wheel">
#     <visual name="visual">
#       <pose frame="">0 0 0 0 -0 0</pose>
#       <geometry>
#         <cylinder>
#           <length>0.05</length>
#           <radius>0.125</radius>
#         </cylinder>
#       </geometry>
#       <material>
#         <ambient>0.494118 0.117647 0.611765 1</ambient>
#         <diffuse>0.49411764705882355 0.11764705882352941 0.611764705882353 1</diffuse>
#       </material>
#       <transparency>0.0</transparency>
#       <cast_shadows>1</cast_shadows>
#     </visual>
#     <kinematic>0</kinematic>
#     <gravity>1</gravity>
#     <self_collide>0</self_collide>
#     <pose frame="">-0.8 -0.525 -0.125 5.76279e-13 1.5707 1.5707</pose>
#     <collision name="collision">
#       <geometry>
#         <cylinder>
#           <length>0.05</length>
#           <radius>0.125</radius>
#         </cylinder>
#       </geometry>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </collision>
#     <inertial>
#       <inertia>
#         <ixy>0.0</ixy>
#         <ixx>0.004114583333333333</ixx>
#         <iyz>0.0</iyz>
#         <iyy>0.004114583333333333</iyy>
#         <ixz>0.0</ixz>
#         <izz>0.0078125</izz>
#       </inertia>
#       <mass>1.0</mass>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </inertial>
#   </link>
#   <link name="chassis">
#     <visual name="visual">
#       <pose frame="">0 0 0 0 -0 0</pose>
#       <geometry>
#         <box>
#           <size>2 1 0.3</size>
#         </box>
#       </geometry>
#       <material>
#         <ambient>0.0156863 0.521569 0.819608 1</ambient>
#         <diffuse>0.01568627450980392 0.5215686274509804 0.8196078431372549 1</diffuse>
#       </material>
#       <transparency>0.0</transparency>
#       <cast_shadows>1</cast_shadows>
#     </visual>
#     <kinematic>0</kinematic>
#     <gravity>1</gravity>
#     <self_collide>0</self_collide>
#     <pose frame="">0 0 0 0 -0 0</pose>
#     <collision name="collision">
#       <geometry>
#         <box>
#           <size>2 1 0.3</size>
#         </box>
#       </geometry>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </collision>
#     <inertial>
#       <inertia>
#         <ixy>0.0</ixy>
#         <ixx>1.8166666666666667</ixx>
#         <iyz>0.0</iyz>
#         <iyy>6.8166666666666655</iyy>
#         <ixz>0.0</ixz>
#         <izz>8.333333333333332</izz>
#       </inertia>
#       <mass>20.0</mass>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </inertial>
#   </link>
#   <link name="camera_link">
#     <visual name="visual">
#       <pose frame="">0 0 0 0 -0 0</pose>
#       <geometry>
#         <box>
#           <size>0.1 0.1 0.1</size>
#         </box>
#       </geometry>
#       <transparency>0.0</transparency>
#       <cast_shadows>1</cast_shadows>
#     </visual>
#     <kinematic>0</kinematic>
#     <gravity>1</gravity>
#     <self_collide>0</self_collide>
#     <pose frame="">1 0 0.2 0 -0 0</pose>
#     <collision name="collision">
#       <geometry>
#         <box>
#           <size>0.1 0.1 0.1</size>
#         </box>
#       </geometry>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </collision>
#     <sensor name="camera" type="camera">
#       <camera name="camera">
#         <horizontal_fov>1.047</horizontal_fov>
#         <distortion>
#           <p2>0.0</p2>
#           <p1>0.0</p1>
#           <k2>0.0</k2>
#           <center>0.5 0.5</center>
#           <k3>0.0</k3>
#           <k1>0.0</k1>
#         </distortion>
#         <depth_camera>
#           <output>depths</output>
#         </depth_camera>
#
#           <width>320.0</width>
#           <height>240.0</height>
#           <format>R8G8B8</format>
#
#         <noise type="none">
#           <bias_stddev>0.0</bias_stddev>
#           <stddev>0.0</stddev>
#           <precision>0.0</precision>
#           <mean>0.0</mean>
#           <bias_mean>0.0</bias_mean>
#         </noise>
#         <clip>
#           <near>0.1</near>
#           <far>100.0</far>
#         </clip>
#         <save enabled="False">
#           <path>__default__</path>
#         </save>
#       </camera>
#       <update_rate>50.0</update_rate>
#       <topic>/camera</topic>
#       <plugin filename="libgazebo_ros_camera.so" name="camera">
#         <cameraName>camera</cameraName>
#         <frameName>camera_link</frameName>
#         <hackBaseline>0.07</hackBaseline>
#         <updateRate>0</updateRate>
#         <distortionK2>0</distortionK2>
#         <robotNamespace></robotNamespace>
#         <distortionK1>0</distortionK1>
#         <cameraInfoTopicName>camera_info</cameraInfoTopicName>
#         <distortionK3>0</distortionK3>
#         <imageTopicName>image_raw</imageTopicName>
#         <distortionT2>0</distortionT2>
#         <distortionT1>0</distortionT1>
#       </plugin>
#       <always_on>1</always_on>
#       <pose frame="">1 0 0.2 0 -0 0</pose>
#       <visualize>1</visualize>
#     </sensor>
#     <inertial>
#       <inertia>
#         <ixy>0.0</ixy>
#         <ixx>1.6666666666666667e-05</ixx>
#         <iyz>0.0</iyz>
#         <iyy>1.6666666666666667e-05</iyy>
#         <ixz>0.0</ixz>
#         <izz>1.6666666666666667e-05</izz>
#       </inertia>
#       <mass>0.01</mass>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </inertial>
#   </link>
#   <link name="caster_wheel">
#     <visual name="visual">
#       <pose frame="">0 0 0 0 -0 0</pose>
#       <geometry>
#         <sphere>
#           <radius>0.125</radius>
#         </sphere>
#       </geometry>
#       <material>
#         <ambient>0.643137 0.74902 0.12549 1</ambient>
#         <diffuse>0.6431372549019608 0.7490196078431373 0.12549019607843137 1</diffuse>
#       </material>
#       <transparency>0.0</transparency>
#       <cast_shadows>1</cast_shadows>
#     </visual>
#     <kinematic>0</kinematic>
#     <gravity>1</gravity>
#     <self_collide>0</self_collide>
#     <pose frame="">0.8 0 -0.125 0 -0 0</pose>
#     <collision name="collision">
#       <surface>
#         <friction>
#           <ode>
#             <slip1>0.0</slip1>
#             <slip2>0.0</slip2>
#             <fdir1>0 0 0</fdir1>
#             <mu2>0.0</mu2>
#             <mu>0.0</mu>
#           </ode>
#           <bullet>
#             <friction>0.0</friction>
#             <rolling_friction>1.0</rolling_friction>
#             <friction2>0.0</friction2>
#             <fdir1>0 0 0</fdir1>
#           </bullet>
#         </friction>
#       </surface>
#       <pose frame="">0 0 0 0 -0 0</pose>
#       <geometry>
#         <sphere>
#           <radius>0.125</radius>
#         </sphere>
#       </geometry>
#     </collision>
#     <inertial>
#       <inertia>
#         <ixy>0.0</ixy>
#         <ixx>0.00625</ixx>
#         <iyz>0.0</iyz>
#         <iyy>0.00625</iyy>
#         <ixz>0.0</ixz>
#         <izz>0.00625</izz>
#       </inertia>
#       <mass>1.0</mass>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </inertial>
#   </link>
#   <link name="contact_link">
#     <visual name="visual">
#       <pose frame="">0 0 0 0 -0 0</pose>
#       <geometry>
#         <cylinder>
#           <length>0.1</length>
#           <radius>0.05</radius>
#         </cylinder>
#       </geometry>
#       <transparency>0.0</transparency>
#       <cast_shadows>1</cast_shadows>
#     </visual>
#     <kinematic>0</kinematic>
#     <gravity>1</gravity>
#     <self_collide>0</self_collide>
#     <pose frame="">1 0 0 0 -0 0</pose>
#     <collision name="collision">
#       <geometry>
#         <cylinder>
#           <length>0.1</length>
#           <radius>0.05</radius>
#         </cylinder>
#       </geometry>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </collision>
#     <sensor name="contact" type="contact">
#       <update_rate>50.0</update_rate>
#       <topic>/bumper</topic>
#       <plugin filename="libgazebo_ros_bumper.so" name="contact">
#         <robotNamespace></robotNamespace>
#         <frameName>world</frameName>
#         <bumperTopicName>/bumper</bumperTopicName>
#       </plugin>
#       <always_on>1</always_on>
#       <contact>
#         <collision>__default__</collision>
#         <collision>collision</collision>
#         <topic>/bumper</topic>
#       </contact>
#       <pose frame="">1 0 0 0 -0 0</pose>
#       <visualize>0</visualize>
#     </sensor>
#     <inertial>
#       <inertia>
#         <ixy>0.0</ixy>
#         <ixx>1.4583333333333333e-05</ixx>
#         <iyz>0.0</iyz>
#         <iyy>1.4583333333333333e-05</iyy>
#         <ixz>0.0</ixz>
#         <izz>1.2500000000000002e-05</izz>
#       </inertia>
#       <mass>0.01</mass>
#       <pose frame="">0 0 0 0 -0 0</pose>
#     </inertial>
#   </link>
#   <pose frame="">0 0 0 0 -0 0</pose>
#   <allow_auto_disable>0</allow_auto_disable>
#   <joint name="right_wheel_joint" type="revolute">
#     <axis>
#       <limit>
#         <effort>-1.0</effort>
#         <lower>-1e+16</lower>
#         <velocity>-1.0</velocity>
#         <upper>1e+16</upper>
#       </limit>
#       <use_parent_model_frame>0</use_parent_model_frame>
#       <dynamics>
#         <friction>0.0</friction>
#         <damping>0.0</damping>
#         <spring_stiffness>0.0</spring_stiffness>
#         <spring_reference>0.0</spring_reference>
#       </dynamics>
#       <xyz>0 0 1</xyz>
#     </axis>
#     <parent>chassis</parent>
#     <pose frame="">0 0 0 0 -0 0</pose>
#     <child>right_wheel</child>
#   </joint>
#   <joint name="contact_joint" type="fixed">
#     <parent>chassis</parent>
#     <pose frame="">0 0 0 0 -0 0</pose>
#     <child>contact_link</child>
#   </joint>
#   <joint name="camera_joint" type="fixed">
#     <parent>chassis</parent>
#     <pose frame="">0 0 0 0 -0 0</pose>
#     <child>camera_link</child>
#   </joint>
#   <joint name="imu_joint" type="fixed">
#     <parent>chassis</parent>
#     <pose frame="">0 0 0 0 -0 0</pose>
#     <child>imu_link</child>
#   </joint>
#   <joint name="caster_wheel_joint" type="fixed">
#     <parent>chassis</parent>
#     <pose frame="">0 0 0 0 -0 0</pose>
#     <child>caster_wheel</child>
#   </joint>
#   <joint name="left_wheel_joint" type="revolute">
#     <axis>
#       <limit>
#         <effort>-1.0</effort>
#         <lower>-1e+16</lower>
#         <velocity>-1.0</velocity>
#         <upper>1e+16</upper>
#       </limit>
#       <use_parent_model_frame>0</use_parent_model_frame>
#       <dynamics>
#         <friction>0.0</friction>
#         <damping>0.0</damping>
#         <spring_stiffness>0.0</spring_stiffness>
#         <spring_reference>0.0</spring_reference>
#       </dynamics>
#       <xyz>0 0 1</xyz>
#     </axis>
#     <parent>chassis</parent>
#     <pose frame="">0 0 0 0 -0 0</pose>
#     <child>left_wheel</child>
#   </joint>
# </model>

# %%
if ROS1_AVAILABLE:
    mobile_base.spawn(
        gazebo_proxy=gazebo_proxy,
        robot_namespace='mobile_base_with_sensor',
        pos=[0, 2.0, 0.5])
# Out:
# line 81.
# line 82.

# %% [markdown]
# ![sim_modified_mobile_base](images/sim_modified_mobile_base.png)

# %%
if ROS1_AVAILABLE:
    simulation.kill_all_tasks()
# Out:
# 2020-09-10 17:18:51,553 | WARNING | task | Task <gazebo> - Killing process tree...
# 2020-09-10 17:18:51,561 | WARNING | task | Sending SIGINT to child process id=8941
# 2020-09-10 17:18:51,562 | WARNING | task | Child process 8941 still running
# 2020-09-10 17:18:51,562 | WARNING | task | Sending SIGINT to child process id=8964
# 2020-09-10 17:18:51,563 | WARNING | task | Child process 8964 still running
# 2020-09-10 17:18:51,564 | WARNING | task | Sending SIGINT to child process id=8959
# 2020-09-10 17:18:51,564 | WARNING | task | Child process 8959 still running
# 2020-09-10 17:18:51,565 | WARNING | task | Sending SIGINT to child process id=9034
# 2020-09-10 17:18:51,566 | WARNING | task | Child process 9034 still running
# 2020-09-10 17:18:51,567 | WARNING | task | Sending SIGINT to child process id=9028
# 2020-09-10 17:18:51,567 | WARNING | task | Child process 9028 still running
# 2020-09-10 17:18:51,568 | WARNING | task | Sending SIGINT to child process id=8940
# 2020-09-10 17:18:51,569 | WARNING | task | Child process 8940 still running
# 2020-09-10 17:19:05,212 | WARNING | task | Process 9028 already terminated
# 2020-09-10 17:19:05,901 | WARNING | task | Process 8964 already terminated
# 2020-09-10 17:19:06,885 | WARNING | task | Process 8940 already terminated
# 2020-09-10 17:19:06,888 | WARNING | task | Process 9034 already terminated
# 2020-09-10 17:19:06,890 | WARNING | task | Process 8959 already terminated
# 2020-09-10 17:19:06,892 | WARNING | task | Process 8941 already terminated
# 2020-09-10 17:19:06,893 | WARNING | task | Kill processes=
# 	 - Gone=[psutil.Process(pid=8941, status='terminated', started='17:06:21'), psutil.Process(pid=8940, status='terminated', exitcode=0, started='17:06:21'), psutil.Process(pid=9034, status='terminated', started='17:06:21'), psutil.Process(pid=9028, status='terminated', started='17:06:21'), psutil.Process(pid=8964, status='terminated', started='17:06:21'), psutil.Process(pid=8959, status='terminated', started='17:06:21')]
# 	 - Alive[]
# 2020-09-10 17:19:06,893 | WARNING | task | Task <roscore> - Killing process tree...
# 2020-09-10 17:19:06,900 | WARNING | task | Sending SIGINT to child process id=8880
# 2020-09-10 17:19:06,901 | WARNING | task | Child process 8880 still running
# 2020-09-10 17:19:06,902 | WARNING | task | Sending SIGINT to child process id=8912
# 2020-09-10 17:19:06,902 | WARNING | task | Child process 8912 still running
# 2020-09-10 17:19:06,903 | WARNING | task | Sending SIGINT to child process id=8896
# 2020-09-10 17:19:06,904 | WARNING | task | Child process 8896 still running
# 2020-09-10 17:19:06,904 | WARNING | task | Sending SIGINT to child process id=8879
# 2020-09-10 17:19:06,905 | WARNING | task | Child process 8879 still running
# 2020-09-10 17:19:07,164 | WARNING | task | Process 8896 already terminated
# 2020-09-10 17:19:07,341 | WARNING | task | Process 8879 already terminated
# 2020-09-10 17:19:07,342 | WARNING | task | Process 8912 already terminated
# 2020-09-10 17:19:07,343 | WARNING | task | Process 8880 already terminated
# 2020-09-10 17:19:07,344 | WARNING | task | Kill processes=
# 	 - Gone=[psutil.Process(pid=8879, status='terminated', exitcode=0, started='17:06:20'), psutil.Process(pid=8880, status='terminated', started='17:06:20'), psutil.Process(pid=8912, status='terminated', started='17:06:20'), psutil.Process(pid=8896, status='terminated', started='17:06:20')]
# 	 - Alive[]
# 2020-09-10 17:19:07,345 | WARNING | process_manager | Required task <roscore> has been terminated, killing all tasks
# 2020-09-10 17:19:07,345 | WARNING | task | Task <gazebo> - Process object is invalid

# %% [markdown]
# ## Export generated model
#
# Simulation models can be exported as an SDF, URDF or as a static Gazebo model.
#
# In case the Gazebo model is exported, it can be stored in a provided folder path or it will be stored per default in `$HOME/.gazebo/models`.

# %%
model_path = mobile_base.to_gazebo_model(overwrite=True)
# Out:
# line 111.
# line 81.
# line 82.
# line 83.
# line 84.

# %%
import os
print('Gazebo model folder: ', model_path)
print(os.listdir(model_path))
# Out:
# Gazebo model folder:  /home/junchuan/.gazebo/models/mobile_base
# ['model.sdf', 'model.config']

# %%
mobile_base.to_urdf().export_xml(os.path.join(model_path, 'model.urdf'))
print(os.listdir(model_path))
# Out:
# line 81.
# line 82.
# ['model.sdf', 'model.urdf', 'model.config']
